# %%
def get_substring_list(original, start_i, end_i):
    global counter
    counter+=1
    if use_cache and memory_data.get((start_i,end_i)):
        print(f'Reuse cache: {(start_i,end_i)}')
        return memory_data.get((start_i,end_i))
    substr_list=[]
    substr_list.append([original[start_i:end_i+1]])
    for i in range(start_i+1, end_i+1):
        head_str = original[start_i:i]
        tail_list=get_substring_list(original, i,end_i)
        for r in tail_list:
            substr_list.append([head_str]+r)
    memory_data[(start_i,end_i)]=substr_list
    return substr_list

# %%
memory_data = {}
use_cache=True
counter=0
original_str = "abcdef"
result = get_substring_list(original_str,0,len(original_str)-1)
print(counter)
for r in result:
    print(r)
print(memory_data)
use_cache=False
counter=0
result = get_substring_list(original_str,0,len(original_str)-1)
print(counter)
for r in result:
    print(r)

# %%
def get_substring_list(original, start_i, end_i):
    if use_cache and memory_data.get((start_i,end_i)):
        return memory_data.get((start_i,end_i))
    substr_list=[]
    substr_list.append([original[start_i:end_i+1]])
    for i in range(start_i+1, end_i+1):
        head_str = original[start_i:i]
        tail_list=get_substring_list(original, i,end_i)
        for r in tail_list:
            substr_list.append([head_str]+r)
    memory_data[(start_i,end_i)]=substr_list
    return substr_list

def has_leading_zero(num_str_list):
    for n in num_str_list:
        if len(n)>1 and n[0]=='0':
            return True
    return False
    
def check_if_fibonacci(num_str_list):
    if len(num_str_list)<3:
        return False
    elif has_leading_zero(num_str_list):
        return False
    else:
        num_list = list(map(int, num_str_list))
        for i in range(2, len(num_list)):
            if num_list[i]!=num_list[i-1]+num_list[i-2]:
                return False
        return True

# %%
memory_data = {}
use_cache=True
input_num = input("Enter the number:")
result = get_substring_list(input_num,0,len(input_num)-1)
is_fibo=False
for num_str_list in result:
    #print(num_str_list)
    if check_if_fibonacci(num_str_list):
        print(list(map(int,num_str_list)))
        is_fibo=True
        break
print(f'Is the data array fibonacci sequence? {is_fibo}')

# %%
memory_data = {}
def get_substring_list(original, start_i, end_i):
    if memory_data.get((start_i,end_i)):
        return memory_data.get((start_i,end_i))
    substr_list=[]
    substr_list.append([original[start_i:end_i+1]])
    for i in range(start_i+1, end_i+1):
        head_str = original[start_i:i]
        tail_list=get_substring_list(original, i,end_i)
        for r in tail_list:
            substr_list.append([head_str]+r)
    memory_data[(start_i,end_i)]=substr_list
    return substr_list

def has_leading_zero(num_str_list):
    for n in num_str_list:
        if len(n)>1 and n[0]=='0':
            return True
    return False
    
def check_if_fibonacci(num_str_list):
    if len(num_str_list)<3:
        return False
    elif has_leading_zero(num_str_list):
        return False
    else:
        num_list = list(map(int, num_str_list))
        for i in range(2, len(num_list)):
            if num_list[i]!=num_list[i-1]+num_list[i-2]:
                return False
        return True

class Solution:
    def splitIntoFibonacci(self, input_num: str) -> List[int]:
        global memory_data 
        memory_data = {}
        result = get_substring_list(input_num,0,len(input_num)-1)
        is_fibo=False
        for num_str_list in result:
            if check_if_fibonacci(num_str_list):
                is_fibo=True
                return list(map(int,num_str_list))
        if not is_fibo:
            return []

# %%
memory_data = {}

def get_substring_list(original, start_i, end_i):
    if memory_data.get((start_i,end_i)):
        return memory_data.get((start_i,end_i))
    substr_list=[]
    if check_larger_number(original[start_i:end_i+1]):
        substr_list.append([original[start_i:end_i+1]])
    for i in range(start_i+1, end_i+1):
        head_str = original[start_i:i]
        if check_larger_number(head_str):
            tail_list=check_if_fibonacci2(get_substring_list(original, i,end_i))
            for r in tail_list:
                new_list = [head_str]+r
                if check_if_fibonacci_leading_zero(new_list):
                    substr_list.append(new_list)
    memory_data[(start_i,end_i)]=substr_list
    return substr_list

def check_larger_number(num_str):
    if len(num_str)>10:
        return False
    num = int(num_str)
    if num> (2**31)-1:
        return False
    return True

def has_leading_zero(num_str_list):
    for n in num_str_list:
        if len(n)>1 and n[0]=='0':
            return True
    return False
    
def check_if_fibonacci_leading_zero(num_str_list):
    if has_leading_zero(num_str_list):
        return False
    else:
        num_list = list(map(int, num_str_list))
        for i in range(2, len(num_list)):
            if num_list[i]!=num_list[i-1]+num_list[i-2]:
                return False
        return True
def check_if_fibonacci(num_str_list):
    num_list = list(map(int, num_str_list))
    for i in range(2, len(num_list)):
        if num_list[i]!=num_list[i-1]+num_list[i-2]:
            return False
    return True
def check_if_fibonacci2(num_str_list2):
    result=[]
    for num_str_list in num_str_list2:
        if has_leading_zero(num_str_list):
            continue
        if len(num_str_list)==1:
            result.append(num_str_list)
            continue
        elif len(num_str_list)==2 and num_str_list[0]<num_str_list[1]:
            result.append(num_str_list)
            continue
        elif check_if_fibonacci(num_str_list):
            result.append(num_str_list)
    return result   

class Solution:
    def splitIntoFibonacci(self, input_num: str) -> List[int]:
        global memory_data 
        memory_data = {}
        result = get_substring_list(input_num,0,len(input_num)-1)
        is_fibo=False
        for num_str_list in result:
            if len(num_str_list)>=3 and check_if_fibonacci_leading_zero(num_str_list):
                is_fibo=True
                return list(map(int,num_str_list))
        if not is_fibo:
            return []
