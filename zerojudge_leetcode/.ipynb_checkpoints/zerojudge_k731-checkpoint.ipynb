# %%
# zerojudge k731. 1. 路徑偵測
def calc():
    global l,r,t
    d1 = (data[1][0]-data[0][0], data[1][1]-data[0][1])
    for pi in range(2, len(data)):
        d2 = (data[pi][0]-data[pi-1][0], data[pi][1]-data[pi-1][1])
        prod = d1[0]*d2[0]+d1[1]*d2[1]
        if prod ==0:
            if d1[0]*d2[1]>0:
                l+=1
            elif d1[0]*d2[1]<0:
                r+=1
            elif d1[1]*d2[0]<0:
                l+=1
            else:
                r+=1
        else:
            if d1[0]*d2[0]>0:
                pass
            elif d1[0]*d2[0]<0:
                t+=1
            elif d1[1]*d2[1]>0:
                pass
            elif d1[1]*d2[1]<0:
                t+=1
            
        
        
# n = int(input())
# data = [(0,0)]
# for _ in range(n):
#     data.append(tuple(map(int, input().split())))
n=9
data = [(0,0),(4,0),(4,9),(4,8),(4,10),(4,2),(4,3),(6,3),(6,10),(6,9)]
l,r,t = 0,0,0
calc()
print(l,r,t)

# %%
# zerojudge k731. 1. 路徑偵測
def calc():
    global l,r,t
    d1 = (data[1][0]-data[0][0], data[1][1]-data[0][1])
    for pi in range(2, len(data)):
        d2 = (data[pi][0]-data[pi-1][0], data[pi][1]-data[pi-1][1])
        prod = d1[0]*d2[0]+d1[1]*d2[1]
        if prod ==0:
            if d1[0]*d2[1]>0:
                l+=1
            elif d1[0]*d2[1]<0:
                r+=1
            elif d1[1]*d2[0]<0:
                l+=1
            else:
                r+=1
        else:
            if d1[0]*d2[0]>0:
                pass
            elif d1[0]*d2[0]<0:
                t+=1
            elif d1[1]*d2[1]>0:
                pass
            elif d1[1]*d2[1]<0:
                t+=1
        d1=d2    
        
        
n = int(input())
data = [(0,0)]
for _ in range(n):
    data.append(tuple(map(int, input().split())))
# n=9
# data = [(0,0),(4,0),(4,9),(4,8),(4,10),(4,2),(4,3),(6,3),(6,10),(6,9)]
# n =2
# data=[(0,0),(2,0),(2,1)]
l,r,t = 0,0,0
calc()
print(l,r,t)
