# %%
# %%prun
# 2024年1月APCS Q4
# use DP top-down, implementaion 2
def dfs(N):
    global counter
    counter+=1
    if N==1:
        return 0 # 0 cost
    hashcode = hash(tuple(data))
    if use_lookup_table and hashcode in lookupTable:
        return lookupTable[hashcode]   
    local_min_cost = 2000*(N-1)
    for i in range(N-1):
        d1 = data[i]
        d2 = data[i+1]
        data.pop(i+1)
        data[i]= d1+d2
        current_cost = abs(d1-d2) # the cost for the summation
        sub_cost = dfs(N-1) 
        if sub_cost+current_cost<local_min_cost:
            local_min_cost = sub_cost+current_cost
        data[i]=d1
        data.insert(i+1,d2)
    if use_lookup_table:
        lookupTable[hashcode]=local_min_cost
    return local_min_cost

# N = int(input())
# data = list(map(int,input().split()))
N = 20
# data = [-2, 1, 3, 2, 4]
import random
random.seed(3)
data = list(random.sample(range(1,21),k=N))
print(data)
lookupTable=dict()
counter=0
use_lookup_table=True
print(dfs(N)) # data, size
print('counter:',counter)
# Out:
# [8, 19, 18, 5, 12, 15, 10, 20, 11, 14, 2, 1, 13, 3, 17, 16, 6, 7, 4, 9]
# 117
# counter: 4980737
#          24904631 function calls (19923881 primitive calls) in 19.053 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 4980737/1   13.364    0.000   19.049   19.049 <string>:3(dfs)
#   4980736    1.609    0.000    1.609    0.000 {method 'insert' of 'list' objects}
#   4980724    1.501    0.000    1.501    0.000 {built-in method builtins.hash}
#   4980736    1.438    0.000    1.438    0.000 {method 'pop' of 'list' objects}
#   4980736    1.134    0.000    1.134    0.000 {built-in method builtins.abs}
#         3    0.001    0.000    0.002    0.001 {built-in method builtins.print}
#        10    0.001    0.000    0.002    0.000 socket.py:621(send)
#         7    0.000    0.000    0.001    0.000 {built-in method select.select}
#     95/89    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         6    0.000    0.000    0.000    0.000 attrsettr.py:65(_get_attr_opt)
#         7    0.000    0.000    0.002    0.000 selectors.py:319(select)
#         7    0.000    0.000    0.243    0.035 base_events.py:1894(_run_once)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#         7    0.000    0.000    0.001    0.000 selectors.py:313(_select)
#         4    0.000    0.000    0.000    0.000 encoder.py:205(iterencode)
#         3    0.000    0.000    0.000    0.000 socket.py:777(recv_multipart)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3638(set)
#         4    0.000    0.000    0.000    0.000 events.py:107(__init__)
#         6    0.000    0.000    0.000    0.000 attrsettr.py:42(__getattr__)
#         8    0.000    0.000    0.000    0.000 iostream.py:624(write)
#         1    0.000    0.000    0.000    0.000 traitlets.py:2642(validate)
#         1    0.000    0.000    0.000    0.000 iostream.py:678(_flush_buffer)
#         2    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#         3    0.000    0.000    0.001    0.000 zmqstream.py:607(_handle_events)
#         8    0.000    0.000    0.043    0.005 {method 'run' of '_contextvars.Context' objects}
#        27    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#         1    0.000    0.000   19.050   19.050 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 random.py:359(sample)
#         2    0.000    0.000    0.000    0.000 iostream.py:117(_run_event_pipe_gc)
#         2    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#         1    0.000    0.000    0.000    0.000 random.py:135(seed)
#        20    0.000    0.000    0.000    0.000 random.py:242(_randbelow_with_getrandbits)
#         8    0.000    0.000    0.043    0.005 events.py:82(_run)
#         9    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#         9    0.000    0.000    0.000    0.000 threading.py:1153(_wait_for_tstate_lock)
#         9    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         1    0.000    0.000    0.000    0.000 iostream.py:685(_rotate_buffer)
#         6    0.000    0.000    0.000    0.000 events.py:32(__init__)
#         2    0.000    0.000    0.000    0.000 iostream.py:126(_event_pipe_gc)
#         9    0.000    0.000    0.000    0.000 threading.py:1220(is_alive)
#        17    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         4    0.000    0.000    0.000    0.000 base_events.py:764(call_at)
#        27    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#         4    0.000    0.000    0.000    0.000 tasks.py:653(sleep)
#         4    0.000    0.000    0.000    0.000 base_events.py:740(call_later)
#        18    0.000    0.000    0.000    0.000 base_events.py:731(time)
#         9    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#         1    0.000    0.000    0.000    0.000 socket.py:698(send_multipart)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:687(_rebuild_io_state)
#        40    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         3    0.000    0.000    0.001    0.000 zmqstream.py:648(_handle_recv)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#        17    0.000    0.000    0.000    0.000 traitlets.py:677(__get__)
#         8    0.000    0.000    0.000    0.000 selector_events.py:746(_process_events)
#         3    0.000    0.000    0.000    0.000 iostream.py:156(_handle_event)
#        14    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         3    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         2    0.000    0.000    0.000    0.000 asyncio.py:210(call_at)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1529(_notify_observers)
#         2    0.000    0.000    0.000    0.000 futures.py:311(_set_result_unless_cancelled)
#         3    0.000    0.000    0.033    0.011 iostream.py:258(schedule)
#      11/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#         6    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         3    0.000    0.000    0.000    0.000 traitlets.py:720(_validate)
#         8    0.000    0.000    0.000    0.000 iostream.py:519(_is_master_process)
#        17    0.000    0.000    0.000    0.000 traitlets.py:630(get)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         4    0.000    0.000    0.000    0.000 encoder.py:183(encode)
#         3    0.000    0.000    0.000    0.000 traitlets.py:709(__set__)
#         3    0.000    0.000    0.000    0.000 traitlets.py:690(set)
#         4    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 events.py:151(cancel)
#        18    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         3    0.000    0.000    0.000    0.000 traitlets.py:729(_cross_validate)
#         1    0.000    0.000   19.050   19.050 <string>:1(<module>)
#         3    0.000    0.000    0.001    0.000 zmqstream.py:580(_run_callback)
#         1    0.000    0.000    0.000    0.000 session.py:690(serialize)
#         3    0.000    0.000    0.001    0.000 asyncio.py:200(_handle_events)
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 ioloop.py:596(call_later)
#         1    0.000    0.000    0.000    0.000 iostream.py:277(_really_send)
#         3    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 {function Random.seed at 0x000001B3395B42C0}
#         2    0.000    0.000    0.000    0.000 base_events.py:445(create_future)
#         1    0.000    0.000    0.041    0.041 ioloop.py:742(_run_callback)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:710(_update_handler)
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        12    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         2    0.000    0.000    0.000    0.000 base_events.py:811(_call_soon)
#         8    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 session.py:649(msg)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3481(validate)
#        27    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#         4    0.000    0.000    0.000    0.000 session.py:92(json_packer)
#         8    0.000    0.000    0.000    0.000 iostream.py:546(_schedule_flush)
#         4    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        11    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.033    0.033 session.py:754(send)
#        12    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:556(_schedule_in_thread)
#        20    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:275(<lambda>)
#         4    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#        50    0.000    0.000    0.000    0.000 typing.py:2119(cast)
#         1    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(validate_elements)
#         1    0.000    0.000    0.000    0.000 {built-in method now}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 session.py:675(sign)
#         2    0.000    0.000    0.000    0.000 base_events.py:782(call_soon)
#         1    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1514(_notify_trait)
#         4    0.000    0.000    0.000    0.000 ioloop.py:541(time)
#         4    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         3    0.000    0.000    0.000    0.000 zmqstream.py:566(sending)
#         3    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         7    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         6    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#         3    0.000    0.000    0.000    0.000 base_events.py:1879(_add_callback)
#         1    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#         3    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         9    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 traitlets.py:1525(notify_change)
#         1    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#         1    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#         1    0.000    0.000    0.033    0.033 iostream.py:585(_flush)
#         3    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2307(validate)
#         6    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 history.py:830(_writeout_output_cache)
#         5    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.033    0.033 iostream.py:270(send_multipart)
#         1    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#         4    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#         9    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         1    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         4    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#         6    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method math.log}
#         2    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#         6    0.000    0.000    0.000    0.000 zmqstream.py:562(receiving)
#         2    0.000    0.000    0.000    0.000 events.py:123(__lt__)
#         4    0.000    0.000    0.000    0.000 hmac.py:117(update)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#        10    0.000    0.000    0.000    0.000 base_events.py:1989(get_debug)
#         1    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#         6    0.000    0.000    0.000    0.000 base_events.py:537(_check_closed)
#         4    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#         2    0.000    0.000    0.000    0.000 events.py:68(cancel)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:341(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3493(validate_elements)
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:215(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 iostream.py:212(_is_master_process)
#         4    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:692(_hooks)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 traitlets.py:2565(_validate_bounds)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 base_events.py:1889(_timer_handle_cancelled)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:254(closed)
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFA865B88B0}
#         1    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}

# %%
# %%time
# 2024年1月APCS Q4
# use DP top-down
def dfs(data, N):
    global counter
    counter+=1
    if N==1:
        return 0 # 0 cost
    hashcode = hash(data)
    if use_lookup_table and hashcode in lookupTable:
        return lookupTable[hashcode]   
    local_min_cost = 2000*(N-1)
    for i in range(N-1):
        arr = []
        for j in range(N):
            if j==i:
                arr.append(data[j]+data[j+1]) # sum of elements of indices j and j+1
                current_cost = abs(data[j]-data[j+1]) # the cost for the summation
                continue
            if j==i+1:
                continue
            arr.append(data[j])
        sub_cost = dfs(tuple(arr), N-1) # use tuple instead of list, only tuple can be the key for dictionary 
        if sub_cost+current_cost<local_min_cost:
            local_min_cost = sub_cost+current_cost
    if use_lookup_table:
        lookupTable[hashcode]=local_min_cost
    return local_min_cost

# N = int(input())
# data = tuple(map(int,input().split()))
N = 20
# data = (-2, 1, 3, 2, 4)
import random
random.seed(3)
data = tuple(random.sample(range(1,21),k=N))
print(data)
lookupTable=dict()
counter=0
use_lookup_table=True
print(dfs(data, N)) # data, size
print('counter:',counter)
# Out:
# (8, 19, 18, 5, 12, 15, 10, 20, 11, 14, 2, 1, 13, 3, 17, 16, 6, 7, 4, 9)
# 117
# counter: 4980737
# 12.143343210220337
# CPU times: total: 9.58 s
# Wall time: 12.1 s

# %%
# 2024年1月APCS Q4
# use DP top-down
# also print the min cost path
def dfs(data, N):
    if N==1:
        return (0,(data,)) # 0 cost, also return the path with the min cost(a tuple)
    hashcode = hash(data)
    if use_lookup_table and hashcode in lookupTable: 
        return lookupTable[hashcode]   
    local_min_cost = 2000*(N-1)
    path_min_cost=None
    for i in range(N-1):
        arr = []
        for j in range(N):
            if j==i:
                arr.append(data[j]+data[j+1]) # sum of elements of indices j and j+1
                current_cost = abs(data[j]-data[j+1]) # the cost for the summation
                continue
            if j==i+1:
                continue
            arr.append(data[j])
        sub_cost, path = dfs(tuple(arr), N-1) 
        if sub_cost+current_cost<local_min_cost:
            path_min_cost = path 
            local_min_cost = sub_cost+current_cost
    path_min_cost = (data,) + path_min_cost
    if use_lookup_table:
        lookupTable[hashcode]=(local_min_cost, path_min_cost) 
    return (local_min_cost,path_min_cost)

# N = int(input())
# data = tuple(map(int,input().split()))
N = 10
# data = (-2, 1, 3, 2, 4)
import random
random.seed(3)
data = tuple(random.sample(range(1,21),k=N))
print(data)
lookupTable=dict()
use_lookup_table=True
print(dfs(data, N)) # data, size

# %%
# 2024年1月APCS Q4
# DFS backtrack, no DP
# implementation 1: dfs() return nothing, use min_cost to record the mimimum cost seen so far
def dfs(data, N, cost): # cost: the top-down total cost so far
    global min_cost
    global counter
    counter+=1
    if N==1:
        if cost<min_cost:
            min_cost=cost
            return
    for i in range(N-1):
        arr = []
        for j in range(N):
            if j==i:
                arr.append(data[j]+data[j+1])
                current_cost = abs(data[j]-data[j+1])
                continue
            if j==i+1:
                continue
            arr.append(data[j])
        if cost+current_cost >= min_cost:
            continue
        dfs(arr, N-1, cost+current_cost) 

# N = int(input())
# data = list(map(int,input().split()))
N = 10
# data = [-2, 1, 3, 2, 4]
import random
random.seed(3)
data = random.sample(range(1,11),k=N)
print(data)
min_cost = 2000*(N-1)
counter=0
arr = []
dfs(data, N, 0) # data, size, cost
print(min_cost)
print('counter:',counter)

# %%
# 2024年1月APCS Q4
# DFS backtrack, no DP
# implementation 2: dfs() return mimimum cost for the sub tree
def dfs(data, N):
    if N==1:
        return 0
    local_min_cost = 2000*(N-1)
    for i in range(N-1):
        arr = []
        for j in range(N):
            if j==i:
                arr.append(data[j]+data[j+1])
                current_cost = abs(data[j]-data[j+1])
                continue
            if j==i+1:
                continue
            arr.append(data[j])
        sub_cost = dfs(arr, N-1) 
        if sub_cost+current_cost<local_min_cost:
            local_min_cost = sub_cost+current_cost
    return local_min_cost

# N = int(input())
# data = list(map(int,input().split()))
N = 5
data = [-2, 1, 3, 2, 4]
arr = []
print(dfs(data, N)) # data, size, cost

# %%
# 2024年1月APCS Q4
# DFS backtrack, no DP
# implementation 3: dfs() return mimimum cost for the current node (ie. sum of the top-down cost to the node and the minimum cost for the sub tree)
def dfs(data, N, cost):  # cost: the top-down total cost so far
    if N==1:
        return cost
    local_min_cost = 2000*(N-1)
    for i in range(N-1):
        arr = []
        for j in range(N):
            if j==i:
                arr.append(data[j]+data[j+1])
                current_cost = abs(data[j]-data[j+1])
                continue
            if j==i+1:
                continue
            arr.append(data[j])
        sub_cost = dfs(arr, N-1, cost+current_cost) 
        if sub_cost<local_min_cost:
            local_min_cost = sub_cost
    return local_min_cost

# N = int(input())
# data = list(map(int,input().split()))
N = 5
data = [-2, 1, 3, 2, 4]
arr = []
print(dfs(data, N, 0)) # data, size, cost

# %%
# 2024年1月APCS Q4
# DFS iteration with a stack
def dfs_iterative():
    global min_cost
    stack = []
    for i in range(N-1): # 0 ~ N-2
        arr = []
        cost = 0
        for j in range(N):
            if j==i:
                arr.append(data[j]+data[j+1])
                cost = abs(data[j]-data[j+1])
                continue
            if j==i+1:
                continue
            arr.append(data[j])
        stack.append((arr,cost)) # store the arr data and cost so far
    #print(stack)
    while stack:
        element = stack.pop()
        parent_data = element[0]
        cost = element[1]
        M = len(parent_data)
        if M==1:
            if cost<min_cost:
                min_cost = cost
            continue
        for i in range(M-1): # 0 ~ M-2
            arr = []
            current_cost = 0
            for j in range(M):
                if j==i:
                    arr.append(parent_data[j]+parent_data[j+1])
                    current_cost = abs(parent_data[j]-parent_data[j+1])
                    continue
                if j==i+1:
                    continue
                arr.append(parent_data[j])
            if current_cost+cost>min_cost: #  add to the stack only if it's less than min_cost
                continue
            stack.append((arr,current_cost+cost))  # store the arr data and cost so far
# N = int(input())
# data = tuple(map(int,input().split()))
N = 15
# data = (-2, 1, 3, 2, 4)
import random
random.seed(3)
data = tuple(random.sample(range(1,21),k=N))
print(data)

min_cost = 2000*(N-1)
dfs_iterative()
print(min_cost)
